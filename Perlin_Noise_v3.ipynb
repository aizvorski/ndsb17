# %%
from pylab import *
# %matplotlib inline

import noise
import numpy as np

# %%
result = np.zeros((256,256))
octaves = 4
freq = 16.0 * octaves
for y in range(256):
    for x in range(256):
        result[x,y] = noise.snoise2(x / freq, y / freq, octaves)
imshow(result)
